# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Split the housing data into train/validate/test sets

# %%
housing = fetch_california_housing()

X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full)
# Out:
# Downloading Cal. housing from https://ndownloader.figshare.com/files/5976036 to /root/scikit_learn_data

# %% [markdown]
# Scale the input features using SciKit StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
import tensorflow
from tensorflow import keras

# %%
model = keras.models.Sequential([
              keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
              keras.layers.Dense(1)
])
model.compile(loss="mean_squared_error", optimizer="sgd")

# %% [markdown]
# Train model

# %%
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 363/363 [==============================] - 1s 2ms/step - loss: 1.0574 - val_loss: 0.5357
# Epoch 2/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4570 - val_loss: 0.4804
# Epoch 3/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4227 - val_loss: 0.4807
# Epoch 4/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.4065 - val_loss: 0.4373
# Epoch 5/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3991 - val_loss: 0.4486
# Epoch 6/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3920 - val_loss: 0.4408
# Epoch 7/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3892 - val_loss: 0.4164
# Epoch 8/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3835 - val_loss: 0.4155
# Epoch 9/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3812 - val_loss: 0.4079
# Epoch 10/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3781 - val_loss: 0.4084
# Epoch 11/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3747 - val_loss: 0.4068
# Epoch 12/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3721 - val_loss: 0.4014
# Epoch 13/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3699 - val_loss: 0.4016
# Epoch 14/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3682 - val_loss: 0.3963
# Epoch 15/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3665 - val_loss: 0.3951
# Epoch 16/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3648 - val_loss: 0.3933
# Epoch 17/20
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3627 - val_loss: 0.3874
# Epoch 18/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3620 - val_loss: 0.3836
# Epoch 19/20
# 363/363 [==============================] - 0s 1ms/step - loss: 0.3595 - val_loss: 0.3939
# Epoch 20/20
# 363/363 [==============================] - 1s 1ms/step - loss: 0.3574 - val_loss: 0.3873

# %%
mse_test = model.evaluate(X_test, y_test)
# Out:
# 162/162 [==============================] - 0s 943us/step - loss: 0.3666

# %% [markdown]
# Predict sample values

# %%
X_new = X_test[:3]
y_pred = model.predict(X_new)
print(y_pred)
# Out:
# [[1.8630146]
#  [3.9837399]
#  [1.3023599]]
